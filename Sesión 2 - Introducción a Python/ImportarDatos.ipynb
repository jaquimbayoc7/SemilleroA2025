# %% [markdown]
# ## ***Importar datos desde diferentes fuentes*** ⛪

# %%
##Importar en excel
import pandas as pd

datos = pd.read_excel('/content/drive/MyDrive/DatosCurso/CovidDiagnosis.xlsx')
datos

datosdos = pd.read_csv('/content/drive/MyDrive/DatosCurso/Datos.csv', sep=';')
datosdos
# Out:
#        Estudiantes Genero  Notas Asignatura
# 0  Julian Quimbayo      M    3.2     ANAPRO
# 1    Andres Castro      M    3.2     ANAPRO
# 2     Lucia Mendez      F    4.5     ANAPRO

# %%
##Función para importar excel o csv
def importarDatos(ruta, extension,sepa=None):
  if extension == 'xlsx':
    return pd.read_excel(ruta)
  elif extension == 'csv':
    return pd.read_csv(ruta, sep=sepa)
  else:
    print('Formato no soportado')

datoexcel = importarDatos('/content/drive/MyDrive/DatosCurso/CovidDiagnosis.xlsx','xlsx')
datoexcel

datoscsv = importarDatos('/content/drive/MyDrive/DatosCurso/Datos.csv', 'csv',';')
datoscsv
# Out:
#        Estudiantes Genero  Notas Asignatura
# 0  Julian Quimbayo      M    3.2     ANAPRO
# 1    Andres Castro      M    3.2     ANAPRO
# 2     Lucia Mendez      F    4.5     ANAPRO

# %%
datoshoy= importarDatos('https://docs.google.com/spreadsheets/d/e/2PACX-1vS7F7pANuD-mCcG3e3k9PpIEqVQz45F7mMGtdTc6ekwXqj6AY1WlD40XAgMhd4_fg/pub?output=csv','csv')
datoshoy
# Out:
# <ipython-input-15-e36ae7503cb1>:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   return pd.read_csv(ruta, sep=sepa)
#      Age      Gender Temperature Headache  Fever       Hospital CovidDiagnosis
# 0   12.0   Masculino         36°       SI    1.0     Moncaleano       positive
# 1   35.0  No Binario          38       NO    0.0      Medilaser       negative
# 2   65.0         NaN         36C      YES    1.0  Carmen Emilia       negative
# 3   78.0         NaN          39      NOP    1.0     Moncaleano       negative
# 4   41.0   Masculino         40.       SI    0.0      Medilaser       positive
# ..   ...         ...         ...      ...    ...            ...            ...
# 94   7.0    Femenino          42      OUI    1.0      Medilaser       positive
# 95   7.0   Masculino          35      OUI    0.0  Carmen Emilia       positive
# ...

# %%
df = pd.read_csv('https://query.data.world/s/ihebhb26xk7xcsyaq5vp7yfn4kzefj?dws=00000')
df['GEO_REGION_POPULATION_COUNT']
# Out:
# 0       38041757
# 1        2880913
# 2       43053054
# 3          77146
# 4       31825299
#           ...
# 3478    96462108
# 3479     4981422
# 3480    29161922
# 3481    17861034
# 3482    14645473
# Name: GEO_REGION_POPULATION_COUNT, Length: 3483, dtype: int64

# %%
datoscsv.to_csv('datosLimpios.csv', index=False)

datoscsv.to_excel('datosLimpios.xlsx', index=False)

datoscsv.to_json('datosLimpios.json')

datoscsv.to_html('datosLimpios.html')
